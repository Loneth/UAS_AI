# %%
# import dependencies
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [1], in <module>
#       1 # import dependencies
# ----> 2 import pandas as pd
#       3 import seaborn as sns
#       4 import matplotlib.pyplot as plt
#
# File c:\Users\NotDa\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\__init__.py:22, in <module>
#      19 del hard_dependencies, dependency, missing_dependencies
#      21 # numpy compat
# ---> 22 from pandas.compat import is_numpy_dev as _is_numpy_dev
#      24 try:
#      25     from pandas._libs import hashtable as _hashtable, lib as _lib, tslib as _tslib
#
# File c:\Users\NotDa\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\compat\__init__.py:14, in <module>
#      11 import sys
#      13 from pandas._typing import F
# ---> 14 from pandas.compat.numpy import (
#      15     is_numpy_dev,
#      16     np_version_under1p19,
#      17     np_version_under1p20,
#      18 )
#      19 from pandas.compat.pyarrow import (
#      20     pa_version_under1p01,
#      21     pa_version_under2p0,
#      22     pa_version_under3p0,
#      23     pa_version_under4p0,
#      24 )
#      26 PY39 = sys.version_info >= (3, 9)
#
# File c:\Users\NotDa\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\compat\numpy\__init__.py:4, in <module>
#       1 """ support numpy compatibility across versions """
#       2 import numpy as np
# ----> 4 from pandas.util.version import Version
#       6 # numpy versioning
#       7 _np_version = np.__version__
#
# File c:\Users\NotDa\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\__init__.py:1, in <module>
# ----> 1 from pandas.util._decorators import (  # noqa:F401
#       2     Appender,
#       3     Substitution,
#       4     cache_readonly,
#       5 )
#       7 from pandas.core.util.hashing import (  # noqa:F401
#       8     hash_array,
#       9     hash_pandas_object,
#      10 )
#      13 def __getattr__(name):
#
# File c:\Users\NotDa\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py:14, in <module>
#       6 from typing import (
#       7     Any,
#       8     Callable,
#       9     Mapping,
#      10     cast,
#      11 )
#      12 import warnings
# ---> 14 from pandas._libs.properties import cache_readonly  # noqa:F401
#      15 from pandas._typing import F
#      18 def deprecate(
#      19     name: str,
#      20     alternative: Callable[..., Any],
#    (...)
#      25     msg: str | None = None,
#      26 ) -> Callable[[F], F]:
#
# File c:\Users\NotDa\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\__init__.py:13, in <module>
#       1 __all__ = [
#       2     "NaT",
#       3     "NaTType",
#    (...)
#       9     "Interval",
#      10 ]
# ---> 13 from pandas._libs.interval import Interval
#      14 from pandas._libs.tslibs import (
#      15     NaT,
#      16     NaTType,
#    (...)
#      21     iNaT,
#      22 )
#
# File c:\Users\NotDa\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\interval.pyx:1, in init pandas._libs.interval()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
# read dataset file
df = pd.read_csv('[Dataset]_Train_(Keryawan).csv')
df
# Out:
#    EmployeeID              Name Department              Position  \
# 0           1          John Doe      Sales         Sales Manager
# 1           2        Jane Smith         HR          HR Executive
# 2           3      Robert Brown         IT     Software Engineer
# 3           4      Mary Johnson    Finance            Accountant
# 4           5  Michael Williams         IT  System Administrator
# 5           6   Patricia Taylor  Marketing  Marketing Specialist
# 6           7    Linda Martinez      Sales       Sales Associate
# 7           8    David Anderson         IT     Software Engineer
# 8           9   Jennifer Thomas         HR            HR Manager
# 9          10     James Jackson    Finance     Financial Analyst
#
#   DateOfJoining DateOfLeaving ReasonForLeaving LastPerformanceRating  \
# 0    2015-06-20    2020-05-15         Resigned             Excellent
# 1    2017-03-15    2021-08-30         Resigned                  Good
# 2    2018-09-10           NaN              NaN             Very Good
# 3    2016-11-05    2019-12-01       Terminated                  Fair
# 4    2019-04-25    2023-01-10         Resigned             Excellent
# 5    2020-07-19           NaN              NaN             Very Good
# 6    2017-01-22    2018-02-28         Resigned                  Fair
# 7    2018-08-15    2022-07-01         Resigned             Excellent
# 8    2015-12-11           NaN              NaN             Very Good
# 9    2019-10-01    2021-11-15         Resigned                  Good
#
#    AnnualSalary  Age  Gender
# 0         75000   35    Male
# 1         60000   29  Female
# 2         85000   32    Male
# 3         55000   40  Female
# 4         70000   28    Male
# 5         62000   30  Female
# 6         45000   27  Female
# 7         90000   34    Male
# 8         80000   45  Female
# 9         68000   33    Male

# %%
# check for null data
null_data = df[df.isna().any(axis=1)]
null_data
# Out:
#    EmployeeID             Name Department              Position DateOfJoining  \
# 2           3     Robert Brown         IT     Software Engineer    2018-09-10
# 5           6  Patricia Taylor  Marketing  Marketing Specialist    2020-07-19
# 8           9  Jennifer Thomas         HR            HR Manager    2015-12-11
#
#   DateOfLeaving ReasonForLeaving LastPerformanceRating  AnnualSalary  Age  \
# 2           NaN              NaN             Very Good         85000   32
# 5           NaN              NaN             Very Good         62000   30
# 8           NaN              NaN             Very Good         80000   45
#
#    Gender
# 2    Male
# 5  Female
# 8  Female

# %%
# delete null data
df = df.dropna()
df
# Out:
#    EmployeeID              Name Department              Position  \
# 0           1          John Doe      Sales         Sales Manager
# 1           2        Jane Smith         HR          HR Executive
# 3           4      Mary Johnson    Finance            Accountant
# 4           5  Michael Williams         IT  System Administrator
# 6           7    Linda Martinez      Sales       Sales Associate
# 7           8    David Anderson         IT     Software Engineer
# 9          10     James Jackson    Finance     Financial Analyst
#
#   DateOfJoining DateOfLeaving ReasonForLeaving LastPerformanceRating  \
# 0    2015-06-20    2020-05-15         Resigned             Excellent
# 1    2017-03-15    2021-08-30         Resigned                  Good
# 3    2016-11-05    2019-12-01       Terminated                  Fair
# 4    2019-04-25    2023-01-10         Resigned             Excellent
# 6    2017-01-22    2018-02-28         Resigned                  Fair
# 7    2018-08-15    2022-07-01         Resigned             Excellent
# 9    2019-10-01    2021-11-15         Resigned                  Good
#
#    AnnualSalary  Age  Gender
# 0         75000   35    Male
# 1         60000   29  Female
# 3         55000   40  Female
# 4         70000   28    Male
# 6         45000   27  Female
# 7         90000   34    Male
# 9         68000   33    Male

# %%
# data visualization
fig,axes = plt.subplots(2,2,figsize=(15,8))

sns.histplot(data=df,x='Gender', ax=axes [0,0],color='red')
sns.histplot(data=df,x='Age', ax=axes [0,1],color='blue')
sns.histplot(data=df,x='Relationship_Status', ax=axes [1,0],color='yellow')
sns.histplot(data=df,x='Hometown', ax=axes [1,1],color='green')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [17], in <module>
#       4 sns.histplot(data=df,x='Gender', ax=axes [0,0],color='red')
#       5 sns.histplot(data=df,x='Age', ax=axes [0,1],color='blue')
# ----> 6 sns.histplot(data=df,x='Relationship_Status', ax=axes [1,0],color='yellow')
#       7 sns.histplot(data=df,x='Hometown', ax=axes [1,1],color='green')
#       8 plt.show()
#
# File c:\Users\NotDa\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:1379, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1358 def histplot(
#    1359     data=None, *,
#    1360     # Vector variables
#    (...)
#    1376     **kwargs,
#    1377 ):
# -> 1379     p = _DistributionPlotter(
#    1380         data=data,
#    1381         variables=dict(x=x, y=y, hue=hue, weights=weights),
#    1382     )
#    1384     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#    1386     if ax is None:
#
# File c:\Users\NotDa\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:110, in _DistributionPlotter.__init__(self, data, variables)
#     104 def __init__(
#     105     self,
#     106     data=None,
#     107     variables={},
#     108 ):
# --> 110     super().__init__(data=data, variables=variables)
#
# File c:\Users\NotDa\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File c:\Users\NotDa\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File c:\Users\NotDa\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_core\data.py:58, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
#      57     data = handle_data_source(data)
# ---> 58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#      61     self.names = names
#
# File c:\Users\NotDa\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_core\data.py:232, in PlotData._assign_variables(self, data, variables)
#     230     else:
#     231         err += "An entry with this name does not appear in `data`."
# --> 232     raise ValueError(err)
#     234 else:
#     235
#     236     # Otherwise, assume the value somehow represents data
#     237
#     238     # Ignore empty data structures
#     239     if isinstance(val, Sized) and len(val) == 0:
#
# ValueError: Could not interpret value `Relationship_Status` for `x`. An entry with this name does not appear in `data`.

# %%
# import sklearn dependency for predictive data analysis
from sklearn.preprocessing import LabelEncoder

encode = LabelEncoder()
# Out:
# c:\Users\NotDa\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\__init__.py:82: UserWarning: A NumPy version >=1.22.4 and <2.3.0 is required for this version of SciPy (detected version 1.22.2)
#   import scipy.linalg  # noqa
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\NotDa\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\_core\__init__.py:23, in <module>
#      22 try:
# ---> 23     from . import multiarray
#      24 except ImportError as exc:
#
# File c:\Users\NotDa\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\_core\multiarray.py:10, in <module>
#       9 import functools
# ---> 10 from . import overrides
#      11 from . import _multiarray_umath
#
# File c:\Users\NotDa\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\_core\overrides.py:8, in <module>
#       7 from .._utils._inspect import getargspec
# ----> 8 from numpy._core._multiarray_umath import (
#       9     add_docstring,  _get_implementing_args, _ArrayFunctionDispatcher)
#      12 ARRAY_FUNCTIONS = set()
#
# ImportError: DLL load failed while importing _multiarray_umath: The specified module could not be found.
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# File c:\Users\NotDa\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\_core\__init__.py:49, in <module>
#      25     import sys
#      26     msg = """
#      27
#      28 IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#    (...)
#      47 """ % (sys.version_info[0], sys.version_info[1], sys.executable,
#      48         __version__, exc)
# ---> 49     raise ImportError(msg)
#      50 finally:
#      51     for envkey in env_added:
#
# ImportError:
#
# IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#
# Importing the numpy C-extensions failed. This error can happen for
# many reasons, often due to issues with your setup or how NumPy was
# installed.
#
# We have compiled some common reasons and troubleshooting tips at:
#
#     https://numpy.org/devdocs/user/troubleshooting-importerror.html
#
# Please note and check the following:
#
#   * The Python version is: Python3.9 from "c:\Users\NotDa\AppData\Local\Programs\Python\Python39\python.exe"
#   * The NumPy version is: "1.22.2"
#
# and make sure that they are the versions you expect.
# Please carefully study the documentation linked above for further help.
#
# Original error was: DLL load failed while importing _multiarray_umath: The specified module could not be found.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [12], in <module>
# ----> 1 from sklearn.preprocessing import LabelEncoder
#       2 encode = LabelEncoder()
#
# File c:\Users\NotDa\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\__init__.py:82, in <module>
#      73     # We are not importing the rest of scikit-learn during the build
#      74     # process, as it may not be compiled yet
#      75 else:
#    (...)
#      79     # in utils.
#      80     # (OpenMP is loaded by importing show_versions right after this block)
#      81     import numpy  # noqa
# ---> 82     import scipy.linalg  # noqa
#      83     from threadpoolctl import ThreadpoolController
#      85     # `_distributor_init` allows distributors to run custom init code.
#      86     # For instance, for the Windows wheel, this is used to pre-load the
#      87     # vcomp shared library runtime for OpenMP embedded in the sklearn/.libs
#    (...)
#      90     # later is linked to the OpenMP runtime to make it possible to introspect
#      91     # it and importing it first would fail if the OpenMP dll cannot be found.
#
# File c:\Users\NotDa\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\linalg\__init__.py:203, in <module>
#       1 """
#       2 ====================================
#       3 Linear algebra (:mod:`scipy.linalg`)
#    (...)
#     200
#     201 """  # noqa: E501
# --> 203 from ._misc import *
#     204 from ._cythonized_array_utils import *
#     205 from ._basic import *
#
# File c:\Users\NotDa\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\linalg\_misc.py:3, in <module>
#       1 import numpy as np
#       2 from numpy.linalg import LinAlgError
# ----> 3 from .blas import get_blas_funcs
#       4 from .lapack import get_lapack_funcs
#       6 __all__ = ['LinAlgError', 'LinAlgWarning', 'norm']
#
# File c:\Users\NotDa\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\linalg\blas.py:213, in <module>
#     210 import numpy as _np
#     211 import functools
# --> 213 from scipy.linalg import _fblas
#     214 try:
#     215     from scipy.linalg import _cblas
#
# ImportError: numpy._core.multiarray failed to import

# %%
# transformation into a table visualization
df['Gender'] = encode.fit_transform(df['Gender'].values)
df['Relationship_Status'] = encode.fit_transform(df['Relationship_Status'].values)
df['Hometown'] = encode.fit_transform(df ['Hometown'].values)
df['Unit'] = encode.fit_transform(df['Unit'].values)
df['Decision_skill_possess'] = encode.fit_transform(df['Decision_skill_possess'].values) 
df['Compensation_and_Benefits'] = encode.fit_transform(df['Compensation_and_Benefits'].values)
df
# Out:
# <ipython-input-7-245873d11b90>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'] = encode.fit_transform(df['Gender'].values)
# <ipython-input-7-245873d11b90>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Relationship_Status'] = encode.fit_transform(df['Relationship_Status'].values)
# <ipython-input-7-245873d11b90>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Hometown'] = encode.fit_transform(df ['Hometown'].values)
# <ipython-input-7-245873d11b90>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Unit'] = encode.fit_transform(df['Unit'].values)
# <ipython-input-7-245873d11b90>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Decision_skill_possess'] = encode.fit_transform(df['Decision_skill_possess'].values)
# <ipython-input-7-245873d11b90>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Compensation_and_Benefits'] = encode.fit_transform(df['Compensation_and_Benefits'].values)
#      Employee_ID  Gender   Age  Education_Level  Relationship_Status  \
# 0      EID_23371       0  42.0                4                    0
# 1      EID_18000       1  24.0                3                    1
# 2       EID_3891       0  58.0                3                    0
# 4      EID_22534       0  31.0                1                    0
# 5       EID_2278       1  54.0                3                    0
# ...          ...     ...   ...              ...                  ...
# 6995   EID_16328       0  23.0                5                    0
# 6996    EID_8387       0  44.0                1                    0
# 6997    EID_8077       0  49.0                3                    1
# 6998   EID_19597       0  47.0                3                    0
# 6999    EID_1640       0  58.0                3                    0
#
#       Hometown  Unit  Decision_skill_possess  Time_of_service  \
# 0            1     2                       2              4.0
# 1            3     3                       0              5.0
# 2            0     8                       2             27.0
# 4            3     3                       2              5.0
# 5            2     7                       2             19.0
# ...        ...   ...                     ...              ...
# 6995         1     5                       1              4.0
# 6996         2     9                       0             16.0
# 6997         3     2                       3             10.0
# 6998         4    10                       1             24.0
# 6999         1     2                       3             22.0
#
#       Time_since_promotion  ...  Compensation_and_Benefits  Work_Life_balance  \
# 0                        4  ...                          2                3.0
# 1                        4  ...                          2                4.0
# 2                        3  ...                          2                1.0
# 4                        4  ...                          3                3.0
# 5                        1  ...                          2                1.0
# ...                    ...  ...                        ...                ...
# 6995                     1  ...                          3                3.0
# 6996                     2  ...                          3                3.0
# 6997                     1  ...                          2                4.0
# 6998                     1  ...                          0                2.0
# 6999                     2  ...                          2                3.0
#
#       VAR1    VAR2    VAR3  VAR4  VAR5  VAR6  VAR7  Attrition_rate
# 0        4  0.7516  1.8688   2.0     4     5     3          0.1841
# 1        3 -0.9612 -0.4537   2.0     3     5     3          0.0670
# 2        4 -0.9612 -0.4537   3.0     3     8     3          0.0851
# 4        1  0.7516 -0.4537   2.0     2     8     2          0.1827
# 5        3 -1.8176  1.8688   2.0     2     8     3          0.7613
# ...    ...     ...     ...   ...   ...   ...   ...             ...
# 6995     1  0.7516 -0.4537   2.0     3     7     3          0.7839
# 6996     2 -0.1048 -2.7762   2.0     4     8     4          0.1055
# 6997     2 -0.1048 -0.4537   2.0     4     8     3          0.7847
# 6998     4  0.7516  1.8688   2.0     3     6     3          0.4162
# 6999     3 -0.1048 -1.6150   3.0     4     5     3          0.0910
#
# [5353 rows x 24 columns]

# %%
# Data normalization
from sklearn.preprocessing import MinMaxScaler

kolom = [col for col in df_beda.columns]
scaler = MinMaxScaler()
scaled = scaler.fit_transform(df_beda[kolom])
df_scaled = pd.DataFrame (scaled,columns=kolom)

df_scaled

# %%
#Visualisasi data
fig,axes = plt.subplots(2,2,figsize=(15,8))

sns.histplot(data=df,x='Gender', ax=axes [0,0],color='red')
sns.histplot(data=df,x='Age', ax=axes [0,1],color='blue')
sns.histplot(data=df,x='Relationship_Status', ax=axes [1,0],color='yellow')
sns.histplot(data=df,x='Hometown', ax=axes [1,1],color='green')
plt.show()

# %%
# import sklearn dependcies
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# spliting data
X_train, X_test, y_train, y_test = train_test_split(df_scaled, df_scaled['Gender'], test_size=0.2, random_state=42)

# %%
# creating model data
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
# model data evaluation
y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')

conf_matrix = confusion_matrix(y_test, y_pred)
print(f'Confusion Matrix:\n{conf_matrix}')

class_report = classification_report(y_test, y_pred)
print(f'Classification Report:\n{class_report}')

df_scaled
# Out:
# Accuracy: 1.0
# Confusion Matrix:
# [[598   0]
#  [  0 473]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       598
#          1.0       1.00      1.00      1.00       473
#
#     accuracy                           1.00      1071
#    macro avg       1.00      1.00      1.00      1071
# weighted avg       1.00      1.00      1.00      1071

# %%
# read dataset test karyawan
new_data = pd.read_csv('[Dataset]_Test_(Karyawan).csv')
new_data = new_data.drop(['Employee_ID'], axis=1)

# %%
# pra-prosesing
new_data = new_data.dropna()

# transformasi
new_data['Gender'] = encode.fit_transform(new_data['Gender'].values)

kolom2 = [col for col in new_data.columns]
scaled2 = scaler.fit_transform(new_data[kolom2])
new_data_scaled = pd.DataFrame (scaled2,columns=kolom2)

new_data_scaled
# Out:
# <ipython-input-22-4a06046d79b4>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['Gender'] = encode.fit_transform(new_data['Gender'].values)
#       Gender       Age  Education_Level  Relationship_Status  Hometown  \
# 0        0.0  0.282609             1.00                  1.0      0.75
# 1        1.0  1.000000             0.25                  1.0      0.50
# 2        1.0  0.717391             0.50                  0.0      0.75
# 3        1.0  0.673913             1.00                  1.0      1.00
# 4        0.0  0.543478             0.50                  0.0      0.25
# ...      ...       ...              ...                  ...       ...
# 2316     1.0  0.608696             0.50                  0.0      0.25
# 2317     0.0  0.347826             0.75                  1.0      1.00
# 2318     0.0  0.282609             0.50                  1.0      0.25
# 2319     0.0  0.695652             0.00                  0.0      0.75
# 2320     0.0  0.565217             0.00                  1.0      0.25
#
#           Unit  Decision_skill_possess  Time_of_service  Time_since_promotion  \
# 0     0.818182                0.666667         0.162791                  1.00
# 1     0.181818                1.000000         0.953488                  0.50
# 2     0.909091                1.000000         0.488372                  0.75
# 3     0.363636                0.000000         0.255814                  1.00
# 4     0.818182                0.666667         0.279070                  1.00
# ...        ...                     ...              ...                   ...
# 2316  0.454545                0.333333         0.348837                  0.50
# 2317  0.363636                0.666667         0.279070                  0.75
# 2318  0.909091                1.000000         0.069767                  0.75
# 2319  0.181818                0.333333         0.534884                  0.25
# 2320  0.909091                1.000000         0.279070                  1.00
#
#       growth_rate  ...  Pay_Scale  Compensation_and_Benefits  \
# 0        0.185185  ...   0.333333                       0.50
# 1        0.962963  ...   0.000000                       0.50
# 2        0.092593  ...   0.777778                       0.75
# 3        0.148148  ...   0.111111                       0.00
# 4        0.500000  ...   0.111111                       0.50
# ...           ...  ...        ...                        ...
# 2316     0.537037  ...   0.888889                       0.50
# 2317     0.722222  ...   0.555556                       0.50
# 2318     0.333333  ...   0.555556                       0.50
# 2319     0.185185  ...   0.555556                       0.75
# 2320     0.925926  ...   0.777778                       1.00
#
#       Work_Life_balance  VAR1      VAR2      VAR3  VAR4  VAR5  VAR6  VAR7
# 0                  0.00  0.50  0.249993  0.500000   0.5  0.00  0.75  0.75
# 1                  0.00  0.75  0.249993  0.749989   0.0  0.25  0.75  0.25
# 2                  0.00  0.75  0.499985  0.749989   0.5  0.00  1.00  0.50
# 3                  0.75  0.50  0.499985  0.749989   0.5  0.25  0.75  0.50
# 4                  0.75  0.75  1.000000  0.749989   0.5  0.25  0.50  0.75
# ...                 ...   ...       ...       ...   ...   ...   ...   ...
# 2316               0.50  0.50  0.249993  0.749989   0.5  0.25  0.25  0.75
# 2317               0.50  0.50  0.749978  0.749989   0.5  0.75  0.50  0.50
# 2318               0.25  0.00  0.499985  0.749989   0.0  0.75  0.50  0.75
# 2319               0.00  1.00  0.749978  0.500000   0.5  0.50  1.00  0.25
# 2320               0.75  0.50  0.749978  0.500000   0.5  0.25  0.75  1.00
#
# [2321 rows x 22 columns]

# %%
df_scaled
# Out:
#       Gender       Age  Education_Level  Relationship_Status  Hometown  \
# 0        0.0  0.500000             0.75                  0.0      0.25
# 1        1.0  0.108696             0.50                  1.0      0.75
# 2        0.0  0.847826             0.50                  0.0      0.00
# 3        0.0  0.260870             0.00                  0.0      0.75
# 4        1.0  0.760870             0.50                  0.0      0.50
# ...      ...       ...              ...                  ...       ...
# 5348     0.0  0.086957             1.00                  0.0      0.25
# 5349     0.0  0.543478             0.00                  0.0      0.50
# 5350     0.0  0.652174             0.50                  1.0      0.75
# 5351     0.0  0.608696             0.50                  0.0      1.00
# 5352     0.0  0.847826             0.50                  0.0      0.25
#
#           Unit  Decision_skill_possess  Time_of_service  Time_since_promotion  \
# 0     0.181818                0.666667         0.093023                  1.00
# 1     0.272727                0.000000         0.116279                  1.00
# 2     0.727273                0.666667         0.627907                  0.75
# 3     0.272727                0.666667         0.116279                  1.00
# 4     0.636364                0.666667         0.441860                  0.25
# ...        ...                     ...              ...                   ...
# 5348  0.454545                0.333333         0.093023                  0.25
# 5349  0.818182                0.000000         0.372093                  0.50
# 5350  0.181818                1.000000         0.232558                  0.25
# 5351  0.909091                0.333333         0.558140                  0.25
# 5352  0.181818                1.000000         0.511628                  0.50
#
#       growth_rate  ...  Pay_Scale  Compensation_and_Benefits  \
# 0        0.240741  ...   0.666667                       0.50
# 1        0.296296  ...   0.555556                       0.50
# 2        0.574074  ...   0.777778                       0.50
# 3        0.777778  ...   0.111111                       0.75
# 4        0.018519  ...   0.888889                       0.50
# ...           ...  ...        ...                        ...
# 5348     0.000000  ...   0.555556                       0.75
# 5349     0.722222  ...   0.333333                       0.75
# 5350     0.722222  ...   0.222222                       0.50
# 5351     0.018519  ...   0.777778                       0.00
# 5352     1.000000  ...   0.444444                       0.50
#
#       Work_Life_balance  VAR1      VAR2      VAR3  VAR4  VAR5  VAR6  VAR7
# 0                  0.50  0.75  0.749978  1.000000   0.5  0.75  0.00  0.50
# 1                  0.75  0.50  0.249993  0.500000   0.5  0.50  0.00  0.50
# 2                  0.00  0.75  0.249993  0.500000   1.0  0.50  0.75  0.50
# 3                  0.50  0.00  0.749978  0.500000   0.5  0.25  0.75  0.25
# 4                  0.00  0.50  0.000000  1.000000   0.5  0.25  0.75  0.50
# ...                 ...   ...       ...       ...   ...   ...   ...   ...
# 5348               0.50  0.00  0.749978  0.500000   0.5  0.50  0.50  0.50
# 5349               0.50  0.25  0.499985  0.000000   0.5  0.75  0.75  0.75
# 5350               0.75  0.25  0.499985  0.500000   0.5  0.75  0.75  0.50
# 5351               0.25  0.75  0.749978  1.000000   0.5  0.50  0.25  0.50
# 5352               0.50  0.50  0.499985  0.249989   1.0  0.75  0.00  0.50
#
# [5353 rows x 22 columns]

# %%
# model testing
new_prediction = model.predict(new_data_scaled)
print(f'New Prediction: {new_prediction}')
# Out:
# New Prediction: [0. 1. 1. ... 0. 0. 0.]
